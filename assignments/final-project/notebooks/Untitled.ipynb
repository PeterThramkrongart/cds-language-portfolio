# %%
import pandas as pd
import numpy as np
import spacy
from spacy_fastlang import LanguageDetector
nlp = spacy.load('en_core_web_sm',disable=["ner"])
nlp.add_pipe("language_detector",  config={"threshold": 0.50, "default_language": "en"})
import os
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.metrics.pairwise import linear_kernel 
from sklearn.preprocessing import StandardScaler
from scipy import spatial
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
data = pd.read_csv(os.path.join("..","data","raw","book_data.csv"), usecols = ['book_authors', 'book_desc',
       'book_pages', 'book_rating', 'book_rating_count', 'book_review_count',
       'book_title', 'genres',"book_format"])
data = data.dropna()
data = data[data["book_review_count"] >= 50]
data["book_pages"] = data.book_pages.str.replace(" pages", "")
data["book_pages"] = data.book_pages.str.replace(" page", "")
data["book_desc"] = data.book_desc.str.replace("\r", "")
data["book_desc"] = data.book_desc.str.replace("\n", "")
scaler = StandardScaler()
data[['book_pages', 'book_rating', 'book_rating_count', 'book_review_count']] = scaler.fit_transform(data[['book_pages', 'book_rating', 'book_rating_count', 'book_review_count']])
book_format = ['Hardcover', 'Paperback']
data = data[data.book_format.isin(book_format)]

# %%
data.head(60)
# Out:
#                                          book_authors  \
# 0                                     Suzanne Collins
# 1                          J.K. Rowling|Mary GrandPré
# 2                                          Harper Lee
# 3   Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                     Stephenie Meyer
# 5                                        Markus Zusak
# 6                           C.S. Lewis|Pauline Baynes
# 7                                       George Orwell
# 8                                   Margaret Mitchell
# 10                                         John Green
# 11                                      Douglas Adams
# 12                                   Shel Silverstein
# 13  Emily Brontë|Richard J. Dunn|David Timson|Char...
# 14                                          Dan Brown
# 15                                      Arthur Golden
# 17                      Oscar Wilde|Jeffrey Eugenides
# 19                                      Veronica Roth
# 20                     Charlotte Brontë|Michael Mason
# 22                                    William Golding
# 23           Paulo Coelho|Alan R. Clarke|Özdemir İnce
# 24                    Fyodor Dostoyevsky|David McDuff
# 26                                    Stephen Chbosky
# 27  Cassandra Clare|Franca Fritz|Heinrich Koop|Fra...
# 28                                   Kathryn Stockett
# 29                                F. Scott Fitzgerald
# 31           E.B. White|Garth Williams|Rosemary Wells
# 32                                    L.M. Montgomery
# 33                                     John Steinbeck
# 34            Bram Stoker|Nina Auerbach|David J. Skal
# 35                                      Aldous Huxley
# 36             Gabriel García Márquez|Gregory Rabassa
# 37  Antoine de Saint-Exupéry|Richard Howard|Dom Ma...
# 38                                    William Goldman
# 39                            Frances Hodgson Burnett
# 40                                      J.D. Salinger
# 41                                    Khaled Hosseini
# 42                                  Madeleine L'Engle
# 45                                       Rick Riordan
# 46                Mark Twain|Guy Cardwell|John Seelye
# 48                                     Maurice Sendak
# 49                                          Dr. Seuss
# 50                         J.K. Rowling|Mary GrandPré
# 51                                        Yann Martel
# 52  Charles Dickens|Richard Maxwell|Hablot Knight ...
# 54                                         Sara Gruen
# 55                   Homer|Robert Fagles|Bernard Knox
# 56                       Vladimir Nabokov|Craig Raine
# 57                                      Kurt Vonnegut
# 58                                      Joseph Heller
# 59  Mary Wollstonecraft Shelley|Percy Bysshe Shell...
# 10           Young Adult|Fiction|Romance|Contemporary
# 11     Science Fiction|Fiction|Humor|Fantasy|Classics
# 12  Childrens|Childrens|Picture Books|Classics|Fic...
# 13                Classics|Fiction|Romance|Literature
# 14                           Fiction|Mystery|Thriller
# 15  Fiction|Historical|Historical Fiction|Romance|...
# 17  Fiction|Classics|Horror|Fantasy|Literature|Got...
# 19  Young Adult|Science Fiction|Dystopia|Fiction|F...
# 20  Classics|Fiction|Romance|Historical|Historical...
# 22  Classics|Fiction|Young Adult|Academic|School|L...
# 23  Fiction|Classics|Fantasy|Philosophy|Novels|Spi...
# 24  Classics|Fiction|Cultural|Russia|Literature|Li...
# 26                   Young Adult|Fiction|Contemporary
# 27     Fantasy|Young Adult|Fantasy|Paranormal|Romance
# 28  Fiction|Historical|Historical Fiction|Historic...
# 29  Classics|Fiction|Academic|School|Literature|Hi...
# 31                         Classics|Childrens|Fiction
# 32  Classics|Fiction|Young Adult|Childrens|Histori...
# 33  Classics|Fiction|Academic|School|Literature|Hi...
# 34  Classics|Horror|Fiction|Fantasy|Paranormal|Vam...
# 35  Classics|Fiction|Science Fiction|Science Ficti...
# 36        Fiction|Classics|Magical Realism|Literature
# 37                 Classics|Fiction|Fantasy|Childrens
# 38  Fantasy|Fiction|Classics|Romance|Humor|Young A...
# 39  Classics|Fiction|Childrens|Young Adult|Histori...
# 40            Classics|Fiction|Young Adult|Literature
# 41              Fiction|Historical|Historical Fiction
# 42  Fantasy|Young Adult|Fiction|Classics|Science F...
# 45      Fantasy|Young Adult|Fantasy|Mythology|Fiction
# 46  Classics|Fiction|Historical|Historical Fiction...
# 48  Childrens|Childrens|Picture Books|Fiction|Clas...
# 49  Childrens|Childrens|Picture Books|Classics|Fic...
# 50                        Fantasy|Young Adult|Fiction
# 51                 Fiction|Fantasy|Classics|Adventure
# 52  Classics|Fiction|Historical|Historical Fiction...
# 54  Fiction|Historical|Historical Fiction|Romance|...
# 55  Classics|Fiction|Poetry|Fantasy|Mythology|Fant...
# 56                        Classics|Fiction|Literature
# 57               Classics|Fiction|Science Fiction|War
# 58  Classics|Fiction|War|Historical|Historical Fic...
# 59  Classics|Fiction|Horror|Science Fiction|Gothic...
# 60  Fiction|Historical|Historical Fiction|Contempo...
# 61   Historical|Historical Fiction|Fiction|Historical
# 62  Horror|Fiction|Fantasy|Science Fiction|Apocaly...
# 63  Young Adult|Fiction|Classics|Science Fiction|D...
# 65  Fiction|Classics|Science Fiction|Dystopia|Scie...
# 66  Classics|Mystery|Fiction|Short Stories|Mystery...
# 67      Fiction|Contemporary|Womens Fiction|Chick Lit
# 69  Classics|Fiction|Feminism|Psychology|Mental He...
# 71             Fiction|Mystery|Thriller|Mystery|Crime
# 73  Classics|Fiction|Historical|Historical Fiction...

# %%
english = []
texts = []
for doc in tqdm(nlp.pipe(data.book_desc,n_process = -1)):
    english.append(doc._.language == 'en')
    texts.append(" ".join([token.lemma_ for token in doc]))
# Out:
# 29517it [01:39, 297.83it/s]

# %%
data["text_processed"] = texts
data = data[english]
data = data.sort_values("book_review_count", ascending = False)
data = data.drop_duplicates(subset = ["book_title"])
data = data.reset_index(drop = True)
data["genres"] = data.genres.str.replace("|", ", ")

# %%
vectorizer = CountVectorizer()

# %%
vectorizer = CountVectorizer()
genre_vec = vectorizer.fit_transform((data["genres"]))

print(type(genre_vec))
np.save(os.path.join("..","data","processed","genre_vec.npy"), genre_vec)
genre_vec = np.load(os.path.join("..","data","processed","genre_vec.npy"), allow_pickle = True)
genre_vec = sparse.csr_matrix(genre_vec.all())

genre_v
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')

# %%
tfidf_vec = tf.fit_transform((data["text_processed"]))

# %%
from sklearn.metrics.pairwise import cosine_similarity
cos_sim = cosine_similarity(tfidf_book_id, tfidf_book_id)

# %%
cos_sim_tfidf = cos_sim

cos_sim

# %%
# Storing indices of the data
indices_genre = pd.Series(data.book_title)
  
def recommendations_genre(title, cosine_sim = cos_sim_genre, indices = indices_genre):
    index = indices[indices == title].index[0]
    similarity_scores = pd.Series(cosine_sim[index])
    return similarity_scores

recs_genre = recommendations_genre("The Fault in Our Stars")

# Storing indices of the data
indices = pd.Series(data.book_title)
  
def recommendations(title, cosine_sim = cos_sim):
    index = indices[indices == title].index[0]
    similarity_scores = pd.Series(cosine_sim[index])
    return similarity_scores

# %%
def recommend(title,df = data, cos_sim_genre = cos_sim_genre,cos_sim_tfidf = cos_sim):
    indices = pd.Series(df.book_title)
    index = indices[indices == title].index[0]
    similarity_scores_tfidf = pd.Series(cos_sim_tfidf[index])
    similarity_scores_genre = pd.Series(cos_sim_genre[index])
    df["tfidf_sim"] = similarity_scores_tfidf
    df["genres_sim"] = similarity_scores_genre
    scaler = StandardScaler()
    df[['tfidf_sim', 'genres_sim']] = scaler.fit_transform(df[['tfidf_sim', 'genres_sim']])
    
    df["rec_score"] = df.tfidf_sim*1+df.genres_sim*0.5+df.book_review_count*0.2+df.book_rating*0.3
    
    df = df[["book_title","book_authors","genres","book_rating_count","book_rating","rec_score"]]
    return df[df.book_title != title].sort_values("rec_score", ascending = False).head(20)

# %%
recommend("1984")

# %%
data = data.drop(["rec_score","tfidf_sim","genres_sim","text_processed", "recs_genre", "recs_score","similarity"], axis = 1)

# %%
data.to_csv(os.path.join("..","data","processed","rec_catalog.csv"),index = False)

# %%
pd.read_csv(os.path.join("..","data","processed","rec_catalog.csv"))

# %%
cos_sim_tfidf.shape

# %%
genre_vec
# Out:
# <23276x674 sparse matrix of type '<class 'numpy.int64'>'
# 	with 138851 stored elements in Compressed Sparse Row format>

# %%
np.load(os.path.join("..","data","processed","genre_vec.npy"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-7830059934c4> in <module>
# ----> 1 np.load(os.path.join("..","data","processed","genre_vec.npy"))
#
# ~/cds-language-portfolio/assignments/final-project/book_recommender_venv/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438             else:
#     439                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 440                                          pickle_kwargs=pickle_kwargs)
#     441         else:
#     442             # Try a pickle
#
# ~/cds-language-portfolio/assignments/final-project/book_recommender_venv/lib/python3.6/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     725         # The array contained Python objects. We need to unpickle the data.
#     726         if not allow_pickle:
# --> 727             raise ValueError("Object arrays cannot be loaded when "
#     728                              "allow_pickle=False")
#     729         if pickle_kwargs is None:
#
# ValueError: Object arrays cannot be loaded when allow_pickle=False

# %%
test = np.load(os.path.join("..","data","processed","cos_sim_genre.npz"))

# %%
result = 1 - spatial.distance.cosine(dataSetI, dataSetII)

# %%
cos_sim_genre
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-cb777bf28376> in <module>
# ----> 1 cos_sim_genre
#
# NameError: name 'cos_sim_genre' is not defined

# %%
a = np.random.randint(0,10,(5,5))
np.array([[5, 2, 0, 4, 1],
       [4, 2, 8, 2, 4],
       [9, 7, 4, 9, 7],
       [4, 6, 0, 1, 3],
       [1, 1, 2, 5, 0]])

from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(a[None,:,3] , a.T[:-1])
# Out:
# array([[0.67449166, 0.68316129, 0.63100845, 1.        ]])

# %%
np.save(os.path.join("..","data","processed","genre_vec.npy"), genre_vec)

# %%
authors_vec = np.load(os.path.join("..","data","processed","authors_vec.npy"),allow_pickle  = True)

# %%
data["test"] = cosine_similarity(tfidf_book_id , tfidf_book_id[0]) + cosine_similarity(tfidf_book_id , tfidf_book_id[0])

# %%
data.sort_values("test",ascending = False)
# Out:
#                              book_authors  \
# 0                         Suzanne Collins
# 8                         Suzanne Collins
# 10                        Suzanne Collins
# 14407                           Kate Egan
# 10634                         Emily Seife
# ...                                   ...
# 12394                       Jack Campbell
# 22100             Plato|Nicholas P. White
# 12384                      Elmore Leonard
# 6995                         Robert McKee
# 19870  Stephen G. Michaud|Hugh Aynesworth
#
#                                                book_desc book_format  \
# 0      Winning will make you famous. Losing means cer...   Paperback
# 8      MY NAME IS KATNISS EVERDEEN. WHY AM I NOT DEAD...   Paperback
# 10     Against all odds, Katniss Everdeen and Peeta M...   Paperback
# 14407  The definitive, richly illustrated, full-color...   Hardcover
# 10634  The New York Times bestselling Hunger Games is...   Paperback
# ...                                                  ...         ...
# 12394  Admiral Geary and Captain Desjani return to th...   Paperback
# 22100  A fluent and accurate new translation of the d...   Paperback
# 12384  Before there was Raylan, there was Sisco... U....   Paperback
# 6995   Robert McKee's screenwriting workshops have ea...   Hardcover
# 19870  "The Only Living Witness towers over the rest ...   Paperback
#
#        book_pages  book_rating  book_rating_count  book_review_count  \
# 0        0.078489     1.255539          21.561603          17.472588
# 8        0.142098     0.130433           7.696353          10.590384
# 10       0.499897     1.105525           8.158029           9.749782
# 14407   -0.645060     1.818092          -0.177976          -0.292400
# 10634   -0.899495     1.518064           0.069080          -0.270043
# ...           ...          ...                ...                ...
# 12394    0.301120     0.130433          -0.201619          -0.282107
# 22100   -0.835887     0.430461          -0.239363          -0.312987
# 12384    0.054636    -0.244603          -0.209544          -0.281997
# 6995     0.444240     0.955511          -0.208739          -0.223891
# 19870   -0.036802     0.392957          -0.234202          -0.309113
#
#                                               book_title  \
# 0                                       The Hunger Games
# 8                                             Mockingjay
# 10                                         Catching Fire
# 14407                      The World of the Hunger Games
# 10634                     The Hunger Games Tribute Guide
# ...                                                  ...
# 12394                                        Dreadnaught
# 22100                                            Sophist
# 12384                                       Out of Sight
# 6995   Story: Substance, Structure, Style, and the Pr...
# 19870  The Only Living Witness: The True Story of Ser...
#
#                                                   genres  \
# 0      Young Adult, Fiction, Science Fiction, Dystopi...
# 8      Young Adult, Science Fiction, Dystopia, Fictio...
# 10     Young Adult, Science Fiction, Dystopia, Fictio...
# 14407             Young Adult, Science Fiction, Dystopia
# 10634             Young Adult, Science Fiction, Dystopia
# ...                                                  ...
# 12394  Science Fiction, Space, Space Opera, War, Mili...
# 22100  Philosophy, Classics, Nonfiction, Literature, ...
# 12384  Fiction, Mystery, Crime, Mystery, Thriller, My...
# 6995        Language, Writing, Nonfiction, Culture, Film
# 19870  Crime, True Crime, Nonfiction, Mystery, Crime,...
#
#                                           text_processed      test
# 0      win will make you famous . lose mean certain d...  2.000000
# 8      MY name be KATNISS EVERDEEN . why be I not dea...  0.238693
# 10     against all odd , Katniss Everdeen and Peeta M...  0.233473
# 14407  the definitive , richly illustrate , full - co...  0.181738
# 10634  the New York Times bestselle Hunger Games be n...  0.143714
# ...                                                  ...       ...
# 12394  Admiral Geary and Captain Desjani return to th...  0.000000
# 22100  a fluent and accurate new translation of the d...  0.000000
# 12384  before there be Raylan , there be Sisco ... U....  0.000000
# 6995   Robert McKee 's screenwrite workshop have earn...  0.000000
# 19870  " the only Living Witness tower over the rest ...  0.000000
#
# [23276 rows x 11 columns]

# %%
# Out:
# <1x2811889 sparse matrix of type '<class 'numpy.float64'>'
# 	with 105 stored elements in Compressed Sparse Row format>

# %%
data = pd.read_csv(os.path.join("..","data","processed","rec_catalog.csv"))
def recommend(title,df = data, genre_vec = genre_vec, tfidf_vec = tfidf_vec):
    indices = pd.Series(df.book_title)
    index = indices[indices == title].index[0]
    print(index)
    df["tfidf_sim"] = cosine_similarity(tfidf_vec , tfidf_vec[index])
    df["genres_sim"] = cosine_similarity(genre_vec , genre_vec[index])

    scaler = StandardScaler()
    df[['tfidf_sim', 'genres_sim']] = scaler.fit_transform(df[['tfidf_sim', 'genres_sim']])
    
    df["rec_score"] = df.tfidf_sim*1+df.genres_sim*0.5+df.book_review_count*0.2+df.book_rating*0.3
    
    df = df[["book_title","book_authors","genres","book_rating_count","book_rating","rec_score"]]
    return df[df.book_title != title].sort_values("rec_score", ascending = False).head(20)

# %%
recommend("1984")
# Out:
# 41
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-90-a89baba38d2b> in <module>
# ----> 1 recommend("1984")
#
# <ipython-input-89-0572470ef107> in recommend(title, df, genre_vec, tfidf_vec)
#       4     index = indices[indices == title].index[0]
#       5     print(index)
# ----> 6     df["tfidf_sim"] = cosine_similarity(tfidf_vec , tfidf_vec[index])
#       7     df["genres_sim"] = cosine_similarity(genre_vec , genre_vec[index])
#       8
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
genre_vec = np.load(os.path.join("..","data","processed","genre_vec.npy"),allow_pickle  = True)

# %%
cosine_similarity(tfidf_vec , tfidf_vec[41])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-114-cc5c4572cfc6> in <module>
# ----> 1 cosine_similarity(tfidf_vec , tfidf_vec[41])
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
"hello|world".split("|")
# Out:
# ['hello', 'world']

# %%
vectorizer = CountVectorizer(tokenizer = test)

# %%
vectorizer.fit_transform(data.book_authors)
# Out:
# <23276x14662 sparse matrix of type '<class 'numpy.int64'>'
# 	with 31432 stored elements in Compressed Sparse Row format>

# %%
# Out:
# <method 'split' of 'str' objects>

# %%
callable(str.split("|"))
# Out:
# False

# %%
def split_authors(string):
    vector =  string.split("|")
    return vector

# %%
callable(test)
# Out:
# True
